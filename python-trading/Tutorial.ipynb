# %%
# !pip install bokeh

# %%
import pandas as pd
import numpy as np

# %%
from bokeh.io import  output_notebook
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource
from bokeh.layouts import row, column, gridplot
from bokeh.models.widgets import Tabs, Panel

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2523">Loading BokehJS ...</span>
#     </div>

# %%
fig = figure()

# %%
show(fig)
# Out:
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: Figure(id='2524', ...)
#   <div class="bk-root" id="de753547-1e92-4378-86b4-7ee88ce4e4f0" data-root-id="2524"></div>
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: Figure(id='2524', ...)

# %%
output_file('filename.html')

# %%
fig1 = figure()

# %%
show(fig1)
# Out:
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: Figure(id='1083', ...)
#   <div class="bk-root" id="c2f6048e-0471-42f0-9739-2a0e1fe54caa" data-root-id="1083"></div>
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: Figure(id='1083', ...)

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

# The figure will be rendered inline in my Jupyter Notebook
output_notebook()

# Example figure
fig = figure(background_fill_color='gray',
             background_fill_alpha=0.5,
             border_fill_color='blue',
             border_fill_alpha=0.25,
             plot_height=300,
             plot_width=500,
             h_symmetry=True,
             x_axis_label='X Label',
             x_axis_type='datetime',
             x_axis_location='above',
             x_range=('2018-01-01', '2018-06-30'),
             y_axis_label='Y Label',
             y_axis_type='linear',
             y_axis_location='left',
             y_range=(0, 100),
             title='Example Figure',
             title_location='right',
             toolbar_location='below',
             tools='save')

# See what it looks like
show(fig)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1242">Loading BokehJS ...</span>
#     </div>
# ...
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: Figure(id='1243', ...)
#   <div class="bk-root" id="2b4a929f-998f-43d1-b296-6cec35429bac" data-root-id="1243"></div>
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: Figure(id='1243', ...)

# %%
fig.grid.grid_line_color = None

# See what it looks like 
show(fig)
# Out:
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: Figure(id='1243', ...)
#   <div class="bk-root" id="b52ac014-8aa1-42e9-a654-dcf6cfa8675a" data-root-id="1243"></div>
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: Figure(id='1243', ...)

# %%
from bokeh.io import output_file

# %%
from bokeh.plotting import figure, show

# %%
x = [1,2,3,4]

# %%
y = [1,3,4,5]

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1844">Loading BokehJS ...</span>
#     </div>

# %%
fig = figure(title = 'my cordinates',plot_height=300,plot_width=400,x_range=(0,4),y_range=(0,5),toolbar_location=None)

# %%
fig.circle(x=x,y=y,color='green',size=20,alpha=0.5)
# Out:
# GlyphRenderer(id='2139', ...)

# %%
show(fig)
# Out:
#   <div class="bk-root" id="2c808d52-26d1-4311-8f5a-33ab0e84d8b5" data-root-id="2102"></div>
